# %% [markdown]
# # Neural Networks Project - Gesture Recognition

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Imagine you are working as a data scientist at a home electronics company which manufactures state of the art smart televisions. You want to develop a cool feature in the smart-TV that can recognise five different gestures performed by the user which will help users control the TV without using a remote.
#
# The gestures are continuously monitored by the webcam mounted on the TV. Each gesture corresponds to a specific command:
#
# . Thumbs up:  Increase the volume
#
# . Thumbs down: Decrease the volume
#
# . Left swipe: 'Jump' backwards 10 seconds
#
# . Right swipe: 'Jump' forward 10 seconds
#
# . Stop: Pause the movie
#
#
# Each video is a sequence of 30 frames (or images). In the next couple of lectures, our subject matter expert Snehansu will walk you through the structure of the dataset.

# %% [markdown]
# ## Understanding the Dataset

# %% [markdown]
# The training data consists of a few hundred videos categorised into one of the five classes. Each video (typically 2-3 seconds long) is divided into a sequence of 30 frames(images). These videos have been recorded by various people performing one of the five gestures in front of a webcam - similar to what the smart TV will use.

# %%
#import data
project_data = 'Project_data'

# %% [markdown]
# ## Gesture Recognition
# In this group project, we are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Import the following libraries to get started.

# %%
import numpy as np
import os
from skimage.transform import resize
from imageio import imread
import datetime
import os
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
import tensorflow as tf
tf.random.set_seed(30)

# %%
import tensorflow as tf

gpus = tf.config.list_physical_devices('GPU')

if not gpus:
    print("GPU device not found")
else:
    for gpu in gpus:
        device_name = gpu.name
        print('Found GPU at: {}'.format(device_name))
# Out:
# GPU device not found

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the batch_size here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
import numpy as np

train_lines = open('Project_data/train.csv').readlines()
val_lines = open('Project_data/val.csv').readlines()

train_doc = np.random.permutation(train_lines)
val_doc = np.random.permutation(val_lines)

batch_size = 64

# %%
## Checking the GPU configuration
# !nvidia-smi
# Out:
# Sun Jun  4 13:29:26 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 532.03                 Driver Version: 532.03       CUDA Version: 12.1     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                      TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf            Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce MX330          WDDM | 00000000:01:00.0 Off |                  N/A |
# | N/A   46C    P0               N/A /  N/A|      0MiB /  2048MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with img_idx, y,z and normalization such that you get high accuracy.

# %%
# Define helper functions
def cropResize(image, y, z):
    h, w = image.shape

    # If smaller image, crop at center for 120x120
    if w == 160:
        image = image[:120, 20:140]

    # Resize every image
    return resize(image, (y, z))

# %%
def normalizeImage(image):
    # Apply normalization
    return image / 255.0

# %%
def preprocessImage(image, y, z):
    return normalizeImage(cropResize(image, y, z))

# %%
def make3dFilter(x):
    return tuple([x] * 3)

def make2dFilter(x):
    return tuple([x] * 2)

# %%
def getBatchData(source_path, t, batch, batch_size, img_tensor):
    [x, y, z] = [img_tensor[0].shape[0], img_tensor[1], img_tensor[2]]
    img_idx = img_tensor[0]
    batch_data = np.zeros((batch_size, x, y, z, 3))  # x is the number of images you use for each video,
    # (y,z) is the final size of the input images and 3 is the number of channels RGB
    batch_labels = np.zeros((batch_size, 5))  # batch_labels is the one hot representation of the output
    for folder in range(batch_size):  # iterate over the batch_size
        imgs = os.listdir(source_path + '/' + t[folder + (batch * batch_size)].split(';')[0])  # read all the images in the folder
        for idx, item in enumerate(img_idx):  # Iterate over the frames/images of a folder to read them in
            image = imread(source_path + '/' + t[folder + (batch * batch_size)].strip().split(';')[0] + '/' + imgs[item]).astype(np.float32)

            # Crop the images and resize them. Note that the images are of 2 different shapes
            # and the conv3D will throw an error if the inputs in a batch have different shapes

            # Separate preprocessImage function is defined for cropping, resizing, and normalizing images
            batch_data[folder, idx, :, :, 0] = preprocessImage(image[:, :, 0], y, z)
            batch_data[folder, idx, :, :, 1] = preprocessImage(image[:, :, 1], y, z)
            batch_data[folder, idx, :, :, 2] = preprocessImage(image[:, :, 2], y, z)

        batch_labels[folder, int(t[folder + (batch * batch_size)].strip().split(';')[2])] = 1
    return batch_data, batch_labels

# %%
def generator(source_path, folder_list, batch_size, img_tensor):
    print('Source path = ', source_path, '; batch size =', batch_size)
    while True:
        t = np.random.permutation(folder_list)
        num_batches = int(len(folder_list) / batch_size)
        for batch in range(num_batches):  # Iterate over the number of batches
            yield getBatchData(source_path, t, batch, batch_size, img_tensor)

        # Write the code for the remaining data points which are left after full batches
        # Checking if any remaining batches are there or not
        if len(folder_list) % batch_size != 0:
            # Updated the batch size and yield
            batch_size = len(folder_list) % batch_size
            yield getBatchData(source_path, t, batch, batch_size, img_tensor)

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
# Set up paths and parameters
curr_dt_time = datetime.datetime.now()
train_path = 'Project_data/train'
val_path = 'Project_data/val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 10
print('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 10

# %%
# Define image tensor size
img_tensor = [np.round(np.linspace(0, 29, 20)).astype(int), 100, 100, 3]
print('# img_tensor =', img_tensor)
# Out:
# # img_tensor = [array([ 0,  2,  3,  5,  6,  8,  9, 11, 12, 14, 15, 17, 18, 20, 21, 23, 24,
#        26, 27, 29]), 100, 100, 3]

# %% [markdown]
# ### Generator Validation

# %%
# Generate the sample validation batch
batch_size = 64
height = 120
width = 120
channels = 3

x = img_tensor[0].shape[0]
y = img_tensor[1]
z = img_tensor[2]

img_tensor = [np.arange(0, 30, 2), 100, 100, 3]

sample_val_generator = generator(val_path, val_doc, batch_size, img_tensor)
sample_val_batch_data, sample_val_batch_labels = next(sample_val_generator)
# Out:
# Source path =  Project_data/val ; batch size = 64

# %%
# plot generated sample images
fig, ax = plt.subplots(1,2)
ax[0].imshow(sample_val_batch_data[16,10,:,:,:])   
ax[1].imshow(sample_val_batch_data[25,10,:,:,:])
plt.show()

# %%
def plotModelHistory(h):
    fig, ax = plt.subplots(1, 2, figsize=(15,4))
    ax[0].plot(h.history['loss'])   
    ax[0].plot(h.history['val_loss'])
    ax[0].legend(['loss','val_loss'])
    ax[0].title.set_text("Train loss vs Validation loss")

    ax[1].plot(h.history['categorical_accuracy'])   
    ax[1].plot(h.history['val_categorical_accuracy'])
    ax[1].legend(['categorical_accuracy','val_categorical_accuracy'])
    ax[1].title.set_text("Train accuracy vs Validation accuracy")
    plt.show()

    print("Max. Training Accuracy", max(h.history['categorical_accuracy']))
    print("Max. Validaiton Accuracy", max(h.history['val_categorical_accuracy']))

# %% [markdown]
# ## Model Building

# %% [markdown]
# Here you make the model using different functionalities that Keras provides. Remember to use Conv3D and MaxPooling3D and not Conv2D and Maxpooling2D for a 3D convolution model. You would want to use TimeDistributed while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation, Dropout, LSTM
from keras.layers.convolutional import Conv3D, MaxPooling3D, Conv2D, MaxPooling2D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers

# %% [markdown]
# ### Base Model

# %%
#write your model here
def defineModel(img_tensor):
    inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

    model = Sequential([
        Conv3D(16, make3dFilter(5), activation='relu', input_shape=inputShape),
        MaxPooling3D(make3dFilter(2), padding='same'),
        BatchNormalization(),

        Conv3D(32, make3dFilter(3), activation='relu'),
        MaxPooling3D(pool_size=(1,2,2), padding='same'),
        BatchNormalization(),

        Conv3D(64, make3dFilter(3), activation='relu'),
        MaxPooling3D(pool_size=(1,2,2), padding='same'),
        BatchNormalization(),

        Flatten(),
        Dense(128, activation='relu'),
        BatchNormalization(),
        Dropout(0.25),

        Dense(64, activation='relu'),
        BatchNormalization(),
        Dropout(0.25),

        Dense(5, activation='softmax')
    ])
    model.compile(optimizer=optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
    return model

model = defineModel(img_tensor)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 11, 96, 96, 16)    6016
#
#  max_pooling3d (MaxPooling3D  (None, 6, 48, 48, 16)    0
#  )
#
#  batch_normalization (BatchN  (None, 6, 48, 48, 16)    64
#  ormalization)
#
#  conv3d_1 (Conv3D)           (None, 4, 46, 46, 32)     13856
#
#  max_pooling3d_1 (MaxPooling  (None, 4, 23, 23, 32)    0
#  3D)
#
#  batch_normalization_1 (Batc  (None, 4, 23, 23, 32)    128
#  hNormalization)
#
#  conv3d_2 (Conv3D)           (None, 2, 21, 21, 64)     55360
#
#  max_pooling3d_2 (MaxPooling  (None, 2, 11, 11, 64)    0
#  3D)
#
#  batch_normalization_2 (Batc  (None, 2, 11, 11, 64)    256
#  hNormalization)
#
#  flatten (Flatten)           (None, 15488)             0
#
#  dense (Dense)               (None, 128)               1982592
#
#  batch_normalization_3 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  batch_normalization_4 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 2,067,621
# Trainable params: 2,067,013
# Non-trainable params: 608
# _________________________________________________________________

# %%
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

# %% [markdown]
# The steps_per_epoch and validation_steps are used by fit_generator to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# ### Model Callbacks Setup

# %%
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)

filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, verbose=1, patience=4)

# callbacks_list = [checkpoint, LR]
callbacks_list = [LR]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %% [markdown]
# ### Test Batch Size & Frames

# %%
def testBatchSize(batch_size, n_frames):
    img_tensor = getImgTensor(n_frames)
    print("Using frames as", img_tensor[0])
    global callbacks_list
    num_epochs = 3
    train_generator = generator(train_path, train_doc, batch_size, img_tensor)
    val_generator = generator(val_path, val_doc, batch_size, img_tensor)
    if (num_train_sequences%batch_size) == 0:
        steps_per_epoch = int(num_train_sequences/batch_size)
    else:
        steps_per_epoch = (num_train_sequences//batch_size) + 1

    if (num_val_sequences%batch_size) == 0:
        validation_steps = int(num_val_sequences/batch_size)
    else:
        validation_steps = (num_val_sequences//batch_size) + 1

    model = defineModel(img_tensor)
    model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                callbacks=callbacks_list, validation_data=val_generator, 
                validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)

# %%
# testBatchSize(batch_size=64, n_frames=30)

# %%
# testBatchSize(batch_size=64, n_frames=16)

# %%
# testBatchSize(batch_size=32, n_frames=30)

# %%
# testBatchSize(batch_size=32, n_frames=16)

# %% [markdown]
# With above observations, we can see that batch size is not impacting training time but number of frames. We will use batch size of 64 as it seems optimal. It is commented as it takes a lot of time to run that is restricting for the notebook to completely run.

# %% [markdown]
# ### Model 1 - Frames-16, Epoc-20

# %%
n_frames = 16
num_epochs = 20
batch_size = 64

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

model1 = Sequential([
    Conv3D(16, make3dFilter(5), activation='relu', input_shape=inputShape),
    MaxPooling3D(make3dFilter(2), padding='same'),
    BatchNormalization(),

    Conv3D(32, make3dFilter(3), activation='relu'),
    MaxPooling3D(pool_size=(1,2,2), padding='same'),
    BatchNormalization(),

    Conv3D(64, make3dFilter(3), activation='relu'),
    MaxPooling3D(pool_size=(1,2,2), padding='same'),
    BatchNormalization(),

    Flatten(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(5, activation='softmax')
], name="conv_3d1")
model1.compile(optimizer=optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model1.summary())

model1_history = model1.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
            callbacks=callbacks_list, validation_data=val_generator, 
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Model: "conv_3d1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_3 (Conv3D)           (None, 12, 96, 96, 16)    6016
#
#  max_pooling3d_3 (MaxPooling  (None, 6, 48, 48, 16)    0
#  3D)
#
#  batch_normalization_5 (Batc  (None, 6, 48, 48, 16)    64
#  hNormalization)
#
#  conv3d_4 (Conv3D)           (None, 4, 46, 46, 32)     13856
#
#  max_pooling3d_4 (MaxPooling  (None, 4, 23, 23, 32)    0
#  3D)
#
#  batch_normalization_6 (Batc  (None, 4, 23, 23, 32)    128
#  hNormalization)
#
#  conv3d_5 (Conv3D)           (None, 2, 21, 21, 64)     55360
#
#  max_pooling3d_5 (MaxPooling  (None, 2, 11, 11, 64)    0
#  3D)
#
#  batch_normalization_7 (Batc  (None, 2, 11, 11, 64)    256
#  hNormalization)
#
#  flatten_1 (Flatten)         (None, 15488)             0
#
#  dense_3 (Dense)             (None, 128)               1982592
#
#  batch_normalization_8 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  batch_normalization_9 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 2,067,621
# Trainable params: 2,067,013
# Non-trainable params: 608
# _________________________________________________________________
# None
# Source path =  Project_data/train ; batch size = 64
# Epoch 1/20
# 11/11 [==============================] - ETA: 0s - loss: 1.3980 - categorical_accuracy: 0.4736 Source path =  Project_data/val ; batch size = 64
# 11/11 [==============================] - 336s 31s/step - loss: 1.3980 - categorical_accuracy: 0.4736 - val_loss: 4.4063 - val_categorical_accuracy: 0.2200 - lr: 0.0010
# Epoch 2/20
# 11/11 [==============================] - 119s 11s/step - loss: 0.8239 - categorical_accuracy: 0.6838 - val_loss: 5.1369 - val_categorical_accuracy: 0.1875 - lr: 0.0010
# Epoch 3/20
# 11/11 [==============================] - 119s 11s/step - loss: 0.9829 - categorical_accuracy: 0.6601 - val_loss: 9.1139 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 4/20
# 11/11 [==============================] - 106s 10s/step - loss: 0.8533 - categorical_accuracy: 0.6738 - val_loss: 6.0586 - val_categorical_accuracy: 0.1875 - lr: 0.0010
# Epoch 5/20
# 11/11 [==============================] - 98s 9s/step - loss: 0.7022 - categorical_accuracy: 0.7512 - val_loss: 2.4970 - val_categorical_accuracy: 0.3438 - lr: 0.0010
# Epoch 6/20
# 11/11 [==============================] - 100s 9s/step - loss: 0.7803 - categorical_accuracy: 0.6890 - val_loss: 3.2670 - val_categorical_accuracy: 0.3750 - lr: 0.0010
# Epoch 7/20
# 11/11 [==============================] - 84s 8s/step - loss: 0.6106 - categorical_accuracy: 0.7635 - val_loss: 3.8858 - val_categorical_accuracy: 0.3750 - lr: 0.0010
# Epoch 8/20
# 11/11 [==============================] - 80s 7s/step - loss: 0.6660 - categorical_accuracy: 0.7647 - val_loss: 3.6049 - val_categorical_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 9/20
# 11/11 [==============================] - 107s 10s/step - loss: 0.6236 - categorical_accuracy: 0.7861 - val_loss: 1.9025 - val_categorical_accuracy: 0.3750 - lr: 0.0010
# Epoch 10/20
# 11/11 [==============================] - 109s 10s/step - loss: 0.6883 - categorical_accuracy: 0.7380 - val_loss: 2.2462 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 11/20
# 11/11 [==============================] - 124s 11s/step - loss: 0.5184 - categorical_accuracy: 0.7914 - val_loss: 2.9761 - val_categorical_accuracy: 0.1250 - lr: 0.0010
# Epoch 12/20
# 11/11 [==============================] - 115s 10s/step - loss: 0.5428 - categorical_accuracy: 0.8128 - val_loss: 1.6450 - val_categorical_accuracy: 0.5000 - lr: 0.0010
# Epoch 13/20
# 11/11 [==============================] - 109s 10s/step - loss: 0.5193 - categorical_accuracy: 0.8021 - val_loss: 2.6859 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 14/20
# 11/11 [==============================] - 98s 9s/step - loss: 0.6188 - categorical_accuracy: 0.7807 - val_loss: 3.0212 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 15/20
# 11/11 [==============================] - 89s 8s/step - loss: 0.4951 - categorical_accuracy: 0.8182 - val_loss: 7.3091 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 16/20
# 11/11 [==============================] - ETA: 0s - loss: 0.5333 - categorical_accuracy: 0.8128
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 11/11 [==============================] - 88s 8s/step - loss: 0.5333 - categorical_accuracy: 0.8128 - val_loss: 2.1611 - val_categorical_accuracy: 0.3750 - lr: 0.0010
# Epoch 17/20
# 11/11 [==============================] - 94s 9s/step - loss: 0.5536 - categorical_accuracy: 0.8075 - val_loss: 3.2237 - val_categorical_accuracy: 0.2500 - lr: 2.0000e-04
# Epoch 18/20
# 11/11 [==============================] - 96s 9s/step - loss: 0.4735 - categorical_accuracy: 0.8128 - val_loss: 2.7605 - val_categorical_accuracy: 0.2500 - lr: 2.0000e-04
# Epoch 19/20
# 11/11 [==============================] - 103s 10s/step - loss: 0.3236 - categorical_accuracy: 0.8770 - val_loss: 1.4963 - val_categorical_accuracy: 0.6250 - lr: 2.0000e-04
# Epoch 20/20
# 11/11 [==============================] - 75s 7s/step - loss: 0.3448 - categorical_accuracy: 0.8663 - val_loss: 2.1529 - val_categorical_accuracy: 0.3750 - lr: 2.0000e-04

# %%
plotModelHistory(model1_history)
# Out:
# Max. Training Accuracy 0.8770053386688232
# Max. Validaiton Accuracy 0.625

# %% [markdown]
# ### Model 2: Frames-30, Epocs-30

# %%
n_frames = 30
num_epochs = 30
batch_size = 64

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

model2 = Sequential([
    Conv3D(16, make3dFilter(5), activation='relu', input_shape=inputShape),
    MaxPooling3D(make3dFilter(2), padding='same'),
    BatchNormalization(),

    Conv3D(32, make3dFilter(3), activation='relu'),
    MaxPooling3D(pool_size=(1,2,2), padding='same'),
    BatchNormalization(),

    Conv3D(64, make3dFilter(3), activation='relu'),
    MaxPooling3D(pool_size=(1,2,2), padding='same'),
    BatchNormalization(),

    Flatten(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(5, activation='softmax')
], name="conv_3d2")
model2.compile(optimizer=optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model2.summary())

model2_history = model2.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
            callbacks=callbacks_list, validation_data=val_generator, 
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Model: "conv_3d2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_6 (Conv3D)           (None, 26, 96, 96, 16)    6016
#
#  max_pooling3d_6 (MaxPooling  (None, 13, 48, 48, 16)   0
#  3D)
#
#  batch_normalization_10 (Bat  (None, 13, 48, 48, 16)   64
#  chNormalization)
#
#  conv3d_7 (Conv3D)           (None, 11, 46, 46, 32)    13856
#
#  max_pooling3d_7 (MaxPooling  (None, 11, 23, 23, 32)   0
#  3D)
#
#  batch_normalization_11 (Bat  (None, 11, 23, 23, 32)   128
#  chNormalization)
#
#  conv3d_8 (Conv3D)           (None, 9, 21, 21, 64)     55360
#
#  max_pooling3d_8 (MaxPooling  (None, 9, 11, 11, 64)    0
#  3D)
#
#  batch_normalization_12 (Bat  (None, 9, 11, 11, 64)    256
#  chNormalization)
#
#  flatten_2 (Flatten)         (None, 69696)             0
#
#  dense_6 (Dense)             (None, 128)               8921216
#
#  batch_normalization_13 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 64)                8256
#
#  batch_normalization_14 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_8 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 9,006,245
# Trainable params: 9,005,637
# Non-trainable params: 608
# _________________________________________________________________
# None
# Source path =  Project_data/train ; batch size = 64
# Epoch 1/30
# 11/11 [==============================] - ETA: 0s - loss: 1.3958 - categorical_accuracy: 0.4676 Source path =  Project_data/val ; batch size = 64
# 11/11 [==============================] - 737s 67s/step - loss: 1.3958 - categorical_accuracy: 0.4676 - val_loss: 11.5627 - val_categorical_accuracy: 0.2600 - lr: 0.0010
# Epoch 2/30
# 11/11 [==============================] - 497s 45s/step - loss: 0.9314 - categorical_accuracy: 0.6245 - val_loss: 10.4592 - val_categorical_accuracy: 0.2656 - lr: 0.0010
# Epoch 3/30
# 11/11 [==============================] - 410s 38s/step - loss: 0.9497 - categorical_accuracy: 0.6245 - val_loss: 8.9006 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 4/30
# 11/11 [==============================] - 363s 32s/step - loss: 0.8048 - categorical_accuracy: 0.6652 - val_loss: 2.2010 - val_categorical_accuracy: 0.3438 - lr: 0.0010
# Epoch 5/30
# 11/11 [==============================] - 309s 28s/step - loss: 0.7661 - categorical_accuracy: 0.7129 - val_loss: 2.5098 - val_categorical_accuracy: 0.1875 - lr: 0.0010
# Epoch 6/30
# 11/11 [==============================] - 284s 26s/step - loss: 0.6996 - categorical_accuracy: 0.7129 - val_loss: 2.1455 - val_categorical_accuracy: 0.1250 - lr: 0.0010
# Epoch 7/30
# 11/11 [==============================] - 282s 25s/step - loss: 0.5616 - categorical_accuracy: 0.7980 - val_loss: 1.3084 - val_categorical_accuracy: 0.5000 - lr: 0.0010
# Epoch 8/30
# 11/11 [==============================] - 292s 27s/step - loss: 0.5352 - categorical_accuracy: 0.8021 - val_loss: 2.0002 - val_categorical_accuracy: 0.5000 - lr: 0.0010
# Epoch 9/30
# 11/11 [==============================] - 282s 25s/step - loss: 0.7088 - categorical_accuracy: 0.7433 - val_loss: 1.0310 - val_categorical_accuracy: 0.3750 - lr: 0.0010
# Epoch 10/30
# 11/11 [==============================] - 341s 31s/step - loss: 0.4863 - categorical_accuracy: 0.8128 - val_loss: 2.1847 - val_categorical_accuracy: 0.1250 - lr: 0.0010
# Epoch 11/30
# 11/11 [==============================] - 271s 25s/step - loss: 0.4542 - categorical_accuracy: 0.8503 - val_loss: 1.7315 - val_categorical_accuracy: 0.3750 - lr: 0.0010
# Epoch 12/30
# 11/11 [==============================] - 274s 25s/step - loss: 0.4753 - categorical_accuracy: 0.8342 - val_loss: 0.9199 - val_categorical_accuracy: 0.5000 - lr: 0.0010
# Epoch 13/30
# 11/11 [==============================] - 274s 25s/step - loss: 0.4779 - categorical_accuracy: 0.8128 - val_loss: 2.9086 - val_categorical_accuracy: 0.1250 - lr: 0.0010
# Epoch 14/30
# 11/11 [==============================] - 268s 24s/step - loss: 0.3863 - categorical_accuracy: 0.8503 - val_loss: 1.6011 - val_categorical_accuracy: 0.3750 - lr: 0.0010
# Epoch 15/30
# 11/11 [==============================] - 287s 26s/step - loss: 0.2654 - categorical_accuracy: 0.9198 - val_loss: 1.4339 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 16/30
# 11/11 [==============================] - ETA: 0s - loss: 0.3382 - categorical_accuracy: 0.8824
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 11/11 [==============================] - 317s 29s/step - loss: 0.3382 - categorical_accuracy: 0.8824 - val_loss: 1.4499 - val_categorical_accuracy: 0.5000 - lr: 0.0010
# Epoch 17/30
# 11/11 [==============================] - 278s 25s/step - loss: 0.2953 - categorical_accuracy: 0.9091 - val_loss: 1.6652 - val_categorical_accuracy: 0.5000 - lr: 2.0000e-04
# Epoch 18/30
# 11/11 [==============================] - 266s 24s/step - loss: 0.2920 - categorical_accuracy: 0.9037 - val_loss: 0.4765 - val_categorical_accuracy: 0.7500 - lr: 2.0000e-04
# Epoch 19/30
# 11/11 [==============================] - 271s 25s/step - loss: 0.2274 - categorical_accuracy: 0.9519 - val_loss: 1.0549 - val_categorical_accuracy: 0.5000 - lr: 2.0000e-04
# Epoch 20/30
# 11/11 [==============================] - 310s 29s/step - loss: 0.1517 - categorical_accuracy: 0.9519 - val_loss: 0.6646 - val_categorical_accuracy: 0.6250 - lr: 2.0000e-04
# Epoch 21/30
# 11/11 [==============================] - 279s 25s/step - loss: 0.2147 - categorical_accuracy: 0.9412 - val_loss: 0.3590 - val_categorical_accuracy: 0.8750 - lr: 2.0000e-04
# Epoch 22/30
# 11/11 [==============================] - 243s 22s/step - loss: 0.1800 - categorical_accuracy: 0.9358 - val_loss: 0.8799 - val_categorical_accuracy: 0.7500 - lr: 2.0000e-04
# Epoch 23/30
# 11/11 [==============================] - 180s 16s/step - loss: 0.1886 - categorical_accuracy: 0.9519 - val_loss: 0.5958 - val_categorical_accuracy: 0.7500 - lr: 2.0000e-04
# Epoch 24/30
# 11/11 [==============================] - 174s 16s/step - loss: 0.1554 - categorical_accuracy: 0.9626 - val_loss: 1.1095 - val_categorical_accuracy: 0.5000 - lr: 2.0000e-04
# Epoch 25/30
# 11/11 [==============================] - ETA: 0s - loss: 0.1554 - categorical_accuracy: 0.9572
# Epoch 25: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 11/11 [==============================] - 208s 19s/step - loss: 0.1554 - categorical_accuracy: 0.9572 - val_loss: 0.5361 - val_categorical_accuracy: 0.8750 - lr: 2.0000e-04
# Epoch 26/30
# 11/11 [==============================] - 173s 16s/step - loss: 0.1587 - categorical_accuracy: 0.9465 - val_loss: 1.0007 - val_categorical_accuracy: 0.6250 - lr: 4.0000e-05
# Epoch 27/30
# 11/11 [==============================] - 173s 16s/step - loss: 0.1530 - categorical_accuracy: 0.9519 - val_loss: 0.3007 - val_categorical_accuracy: 0.8750 - lr: 4.0000e-05
# Epoch 28/30
# 11/11 [==============================] - 187s 17s/step - loss: 0.0834 - categorical_accuracy: 0.9893 - val_loss: 1.3629 - val_categorical_accuracy: 0.6250 - lr: 4.0000e-05
# Epoch 29/30
# 11/11 [==============================] - 230s 20s/step - loss: 0.1416 - categorical_accuracy: 0.9572 - val_loss: 0.8350 - val_categorical_accuracy: 0.7500 - lr: 4.0000e-05
# Epoch 30/30
# 11/11 [==============================] - 195s 18s/step - loss: 0.1472 - categorical_accuracy: 0.9572 - val_loss: 0.4447 - val_categorical_accuracy: 0.7500 - lr: 4.0000e-05

# %%
plotModelHistory(model2_history)
# Out:
# Max. Training Accuracy 0.9893048405647278
# Max. Validaiton Accuracy 0.875

# %% [markdown]
# Reduce parameters, with padding in Conv3D layers and filter of (3,3,3).

# %% [markdown]
# ### Model 3: Frames-30, Epocs-20, Reduced parameters

# %%
n_frames = 30
num_epochs = 20
batch_size = 64

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

model3 = Sequential([
    Conv3D(16, make3dFilter(3), padding='same', activation='relu', input_shape=inputShape),
    MaxPooling3D(make3dFilter(2), padding='same'),
    BatchNormalization(),

    Conv3D(32, make3dFilter(3), padding='same', activation='relu'),
    MaxPooling3D(pool_size=(2), padding='same'),
    BatchNormalization(),

    Conv3D(64, make3dFilter(3), padding='same', activation='relu'),
    MaxPooling3D(pool_size=(2), padding='same'),
    BatchNormalization(),

    Flatten(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(5, activation='softmax')
], name="conv_3d3")
model3.compile(optimizer=optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model3.summary())

model3_history = model3.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
            callbacks=callbacks_list, validation_data=val_generator, 
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Model: "conv_3d3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_12 (Conv3D)          (None, 30, 100, 100, 16)  1312
#
#  max_pooling3d_12 (MaxPoolin  (None, 15, 50, 50, 16)   0
#  g3D)
#
#  batch_normalization_20 (Bat  (None, 15, 50, 50, 16)   64
#  chNormalization)
#
#  conv3d_13 (Conv3D)          (None, 15, 50, 50, 32)    13856
#
#  max_pooling3d_13 (MaxPoolin  (None, 8, 25, 25, 32)    0
#  g3D)
#
#  batch_normalization_21 (Bat  (None, 8, 25, 25, 32)    128
#  chNormalization)
#
#  conv3d_14 (Conv3D)          (None, 8, 25, 25, 64)     55360
#
#  max_pooling3d_14 (MaxPoolin  (None, 4, 13, 13, 64)    0
#  g3D)
#
#  batch_normalization_22 (Bat  (None, 4, 13, 13, 64)    256
#  chNormalization)
#
#  flatten_4 (Flatten)         (None, 43264)             0
#
#  dense_12 (Dense)            (None, 128)               5537920
#
#  batch_normalization_23 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  dense_13 (Dense)            (None, 64)                8256
#
#  batch_normalization_24 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_9 (Dropout)         (None, 64)                0
#
#  dense_14 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 5,618,245
# Trainable params: 5,617,637
# Non-trainable params: 608
# _________________________________________________________________
# None
# Source path =  Project_data/train ; batch size = 64
# Epoch 1/20
# 11/11 [==============================] - ETA: 0s - loss: 1.2974 - categorical_accuracy: 0.5219 Source path =  Project_data/val ; batch size = 64
# 11/11 [==============================] - 561s 51s/step - loss: 1.2974 - categorical_accuracy: 0.5219 - val_loss: 3.1904 - val_categorical_accuracy: 0.3000 - lr: 0.0010
# Epoch 2/20
# 11/11 [==============================] - 225s 21s/step - loss: 0.6121 - categorical_accuracy: 0.7866 - val_loss: 2.6771 - val_categorical_accuracy: 0.1719 - lr: 0.0010
# Epoch 3/20
# 11/11 [==============================] - 222s 20s/step - loss: 0.7320 - categorical_accuracy: 0.7194 - val_loss: 2.3256 - val_categorical_accuracy: 0.2321 - lr: 0.0010
# Epoch 4/20
# 11/11 [==============================] - 195s 18s/step - loss: 0.5503 - categorical_accuracy: 0.8112 - val_loss: 2.9075 - val_categorical_accuracy: 0.2188 - lr: 0.0010
# Epoch 5/20
# 11/11 [==============================] - 176s 16s/step - loss: 0.5319 - categorical_accuracy: 0.7895 - val_loss: 3.0454 - val_categorical_accuracy: 0.1562 - lr: 0.0010
# Epoch 6/20
# 11/11 [==============================] - 167s 15s/step - loss: 0.5074 - categorical_accuracy: 0.8086 - val_loss: 1.5233 - val_categorical_accuracy: 0.1250 - lr: 0.0010
# Epoch 7/20
# 11/11 [==============================] - 166s 15s/step - loss: 0.4818 - categorical_accuracy: 0.8030 - val_loss: 2.9668 - val_categorical_accuracy: 0.3750 - lr: 0.0010
# Epoch 8/20
# 11/11 [==============================] - 216s 20s/step - loss: 0.3627 - categorical_accuracy: 0.8717 - val_loss: 5.3185 - val_categorical_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 9/20
# 11/11 [==============================] - 223s 20s/step - loss: 0.4472 - categorical_accuracy: 0.8610 - val_loss: 2.7088 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 10/20
# 11/11 [==============================] - ETA: 0s - loss: 0.4111 - categorical_accuracy: 0.8503
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 11/11 [==============================] - 241s 22s/step - loss: 0.4111 - categorical_accuracy: 0.8503 - val_loss: 2.0073 - val_categorical_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 11/20
# 11/11 [==============================] - 205s 18s/step - loss: 0.2925 - categorical_accuracy: 0.8930 - val_loss: 2.3416 - val_categorical_accuracy: 0.3750 - lr: 2.0000e-04
# Epoch 12/20
# 11/11 [==============================] - 217s 20s/step - loss: 0.3604 - categorical_accuracy: 0.8770 - val_loss: 1.4421 - val_categorical_accuracy: 0.2500 - lr: 2.0000e-04
# Epoch 13/20
# 11/11 [==============================] - 213s 19s/step - loss: 0.2916 - categorical_accuracy: 0.8930 - val_loss: 2.1083 - val_categorical_accuracy: 0.3750 - lr: 2.0000e-04
# Epoch 14/20
# 11/11 [==============================] - 205s 19s/step - loss: 0.2220 - categorical_accuracy: 0.9251 - val_loss: 1.1056 - val_categorical_accuracy: 0.3750 - lr: 2.0000e-04
# Epoch 15/20
# 11/11 [==============================] - 201s 18s/step - loss: 0.2469 - categorical_accuracy: 0.9091 - val_loss: 0.8991 - val_categorical_accuracy: 0.5000 - lr: 2.0000e-04
# Epoch 16/20
# 11/11 [==============================] - 198s 18s/step - loss: 0.1750 - categorical_accuracy: 0.9626 - val_loss: 1.5152 - val_categorical_accuracy: 0.3750 - lr: 2.0000e-04
# Epoch 17/20
# 11/11 [==============================] - 175s 16s/step - loss: 0.2384 - categorical_accuracy: 0.8877 - val_loss: 1.3615 - val_categorical_accuracy: 0.6250 - lr: 2.0000e-04
# Epoch 18/20
# 11/11 [==============================] - 174s 16s/step - loss: 0.1990 - categorical_accuracy: 0.9358 - val_loss: 1.8710 - val_categorical_accuracy: 0.0000e+00 - lr: 2.0000e-04
# Epoch 19/20
# 11/11 [==============================] - ETA: 0s - loss: 0.2730 - categorical_accuracy: 0.9198
# Epoch 19: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 11/11 [==============================] - 170s 15s/step - loss: 0.2730 - categorical_accuracy: 0.9198 - val_loss: 1.5816 - val_categorical_accuracy: 0.3750 - lr: 2.0000e-04
# Epoch 20/20
# 11/11 [==============================] - 185s 17s/step - loss: 0.1726 - categorical_accuracy: 0.9519 - val_loss: 1.4480 - val_categorical_accuracy: 0.5000 - lr: 4.0000e-05

# %%
plotModelHistory(model3_history)
# Out:
# Max. Training Accuracy 0.9625668525695801
# Max. Validaiton Accuracy 0.625

# %% [markdown]
# ### Model 4: Frames-20, Same pooling in Conv3D layer

# %%
n_frames = 20
num_epochs = 20
batch_size = 64

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

model4 = Sequential([
    Conv3D(16, make3dFilter(3), padding='same', activation='relu', input_shape=inputShape),
    MaxPooling3D(make3dFilter(2), padding='same'),
    BatchNormalization(),

    Conv3D(32, make3dFilter(3), padding='same', activation='relu'),
    MaxPooling3D(pool_size=(2), padding='same'),
    BatchNormalization(),

    Conv3D(64, make3dFilter(3), padding='same', activation='relu'),
    MaxPooling3D(pool_size=(2), padding='same'),
    BatchNormalization(),

    Conv3D(128, make3dFilter(3), padding='same', activation='relu'),
    MaxPooling3D(pool_size=(2), padding='same'),
    BatchNormalization(),

    Flatten(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(5, activation='softmax')
], name="conv_3d4")
model4.compile(optimizer=optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model4.summary())

model4_history = model4.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
            callbacks=callbacks_list, validation_data=val_generator, 
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Model: "conv_3d4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_15 (Conv3D)          (None, 20, 100, 100, 16)  1312
#
#  max_pooling3d_15 (MaxPoolin  (None, 10, 50, 50, 16)   0
#  g3D)
#
#  batch_normalization_25 (Bat  (None, 10, 50, 50, 16)   64
#  chNormalization)
#
#  conv3d_16 (Conv3D)          (None, 10, 50, 50, 32)    13856
#
#  max_pooling3d_16 (MaxPoolin  (None, 5, 25, 25, 32)    0
#  g3D)
#
#  batch_normalization_26 (Bat  (None, 5, 25, 25, 32)    128
#  chNormalization)
#
#  conv3d_17 (Conv3D)          (None, 5, 25, 25, 64)     55360
#
#  max_pooling3d_17 (MaxPoolin  (None, 3, 13, 13, 64)    0
#  g3D)
#
#  batch_normalization_27 (Bat  (None, 3, 13, 13, 64)    256
#  chNormalization)
#
#  conv3d_18 (Conv3D)          (None, 3, 13, 13, 128)    221312
#
#  max_pooling3d_18 (MaxPoolin  (None, 2, 7, 7, 128)     0
#  g3D)
#
#  batch_normalization_28 (Bat  (None, 2, 7, 7, 128)     512
#  chNormalization)
#
#  flatten_5 (Flatten)         (None, 12544)             0
#
#  dense_15 (Dense)            (None, 128)               1605760
#
#  batch_normalization_29 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_10 (Dropout)        (None, 128)               0
#
#  dense_16 (Dense)            (None, 64)                8256
#
#  batch_normalization_30 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_11 (Dropout)        (None, 64)                0
#
#  dense_17 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 1,907,909
# Trainable params: 1,907,045
# Non-trainable params: 864
# _________________________________________________________________
# None
# Source path =  Project_data/train ; batch size = 64
# Epoch 1/20
# 11/11 [==============================] - ETA: 0s - loss: 1.3837 - categorical_accuracy: 0.5068 Source path =  Project_data/val ; batch size = 64
# 11/11 [==============================] - 508s 47s/step - loss: 1.3837 - categorical_accuracy: 0.5068 - val_loss: 1.6380 - val_categorical_accuracy: 0.2700 - lr: 0.0010
# Epoch 2/20
# 11/11 [==============================] - 187s 17s/step - loss: 0.8538 - categorical_accuracy: 0.6680 - val_loss: 1.8845 - val_categorical_accuracy: 0.1562 - lr: 0.0010
# Epoch 3/20
# 11/11 [==============================] - 170s 16s/step - loss: 0.8549 - categorical_accuracy: 0.6838 - val_loss: 1.7046 - val_categorical_accuracy: 0.3214 - lr: 0.0010
# Epoch 4/20
# 11/11 [==============================] - 162s 15s/step - loss: 0.9123 - categorical_accuracy: 0.6652 - val_loss: 1.6772 - val_categorical_accuracy: 0.3750 - lr: 0.0010
# Epoch 5/20
# 11/11 [==============================] - ETA: 0s - loss: 0.5445 - categorical_accuracy: 0.7990
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 11/11 [==============================] - 147s 13s/step - loss: 0.5445 - categorical_accuracy: 0.7990 - val_loss: 2.0253 - val_categorical_accuracy: 0.1562 - lr: 0.0010
# Epoch 6/20
# 11/11 [==============================] - 128s 12s/step - loss: 0.6069 - categorical_accuracy: 0.7464 - val_loss: 2.0398 - val_categorical_accuracy: 0.5000 - lr: 2.0000e-04
# Epoch 7/20
# 11/11 [==============================] - 144s 13s/step - loss: 0.5498 - categorical_accuracy: 0.7783 - val_loss: 2.4488 - val_categorical_accuracy: 0.1250 - lr: 2.0000e-04
# Epoch 8/20
# 11/11 [==============================] - 136s 12s/step - loss: 0.3997 - categorical_accuracy: 0.8396 - val_loss: 1.7686 - val_categorical_accuracy: 0.1250 - lr: 2.0000e-04
# Epoch 9/20
# 11/11 [==============================] - 138s 13s/step - loss: 0.4438 - categorical_accuracy: 0.8235 - val_loss: 1.3817 - val_categorical_accuracy: 0.2500 - lr: 2.0000e-04
# Epoch 10/20
# 11/11 [==============================] - 133s 12s/step - loss: 0.3719 - categorical_accuracy: 0.8663 - val_loss: 1.9531 - val_categorical_accuracy: 0.5000 - lr: 2.0000e-04
# Epoch 11/20
# 11/11 [==============================] - 132s 12s/step - loss: 0.3484 - categorical_accuracy: 0.8877 - val_loss: 1.7441 - val_categorical_accuracy: 0.1250 - lr: 2.0000e-04
# Epoch 12/20
# 11/11 [==============================] - 144s 13s/step - loss: 0.4049 - categorical_accuracy: 0.8556 - val_loss: 2.5482 - val_categorical_accuracy: 0.0000e+00 - lr: 2.0000e-04
# Epoch 13/20
# 11/11 [==============================] - ETA: 0s - loss: 0.3517 - categorical_accuracy: 0.8556
# Epoch 13: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 11/11 [==============================] - 110s 10s/step - loss: 0.3517 - categorical_accuracy: 0.8556 - val_loss: 1.4978 - val_categorical_accuracy: 0.5000 - lr: 2.0000e-04
# Epoch 14/20
# 11/11 [==============================] - 113s 10s/step - loss: 0.3400 - categorical_accuracy: 0.9037 - val_loss: 1.7917 - val_categorical_accuracy: 0.1250 - lr: 4.0000e-05
# Epoch 15/20
# 11/11 [==============================] - 141s 13s/step - loss: 0.3916 - categorical_accuracy: 0.8610 - val_loss: 2.0380 - val_categorical_accuracy: 0.1250 - lr: 4.0000e-05
# Epoch 16/20
# 11/11 [==============================] - 110s 10s/step - loss: 0.3463 - categorical_accuracy: 0.8984 - val_loss: 1.8065 - val_categorical_accuracy: 0.2500 - lr: 4.0000e-05
# Epoch 17/20
# 11/11 [==============================] - ETA: 0s - loss: 0.2793 - categorical_accuracy: 0.9144
# Epoch 17: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 11/11 [==============================] - 119s 11s/step - loss: 0.2793 - categorical_accuracy: 0.9144 - val_loss: 2.2285 - val_categorical_accuracy: 0.1250 - lr: 4.0000e-05
# Epoch 18/20
# 11/11 [==============================] - 133s 12s/step - loss: 0.2625 - categorical_accuracy: 0.9198 - val_loss: 1.3535 - val_categorical_accuracy: 0.3750 - lr: 8.0000e-06
# Epoch 19/20
# 11/11 [==============================] - 137s 12s/step - loss: 0.2977 - categorical_accuracy: 0.8877 - val_loss: 1.6650 - val_categorical_accuracy: 0.5000 - lr: 8.0000e-06
# Epoch 20/20
# 11/11 [==============================] - 133s 12s/step - loss: 0.3661 - categorical_accuracy: 0.8717 - val_loss: 2.1664 - val_categorical_accuracy: 0.0000e+00 - lr: 8.0000e-06

# %%
plotModelHistory(model4_history)
# Out:
# Max. Training Accuracy 0.9197860956192017
# Max. Validaiton Accuracy 0.5

# %% [markdown]
# ### Model 5: Frames:20, Epocs-20, BS-64, reduced kernel to (2,2,2), switching BatchNormalization before MaxPooling.

# %%
n_frames = 20
num_epochs = 20
batch_size = 64

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

model5 = Sequential([
    Conv3D(16, make3dFilter(2), padding='same', activation='relu', input_shape=inputShape),
    BatchNormalization(),
    MaxPooling3D(make3dFilter(2)),

    Conv3D(32, make3dFilter(2), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling3D(pool_size=(2)),

    Conv3D(64, make3dFilter(2), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling3D(pool_size=(2)),

    Conv3D(128, make3dFilter(2), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling3D(pool_size=(2)),

    Flatten(),
    Dense(256, activation='relu'),
    # BatchNormalization(),
    # Dropout(0.3),

    Dense(128, activation='relu'),
    # BatchNormalization(),
    # Dropout(0.2),

    Dense(5, activation='softmax')
], name="conv_3d5")
model5.compile(optimizer=optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model5.summary())

model5_history = model5.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
            callbacks=callbacks_list, validation_data=val_generator, 
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Model: "conv_3d5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_19 (Conv3D)          (None, 20, 100, 100, 16)  400
#
#  batch_normalization_31 (Bat  (None, 20, 100, 100, 16)  64
#  chNormalization)
#
#  max_pooling3d_19 (MaxPoolin  (None, 10, 50, 50, 16)   0
#  g3D)
#
#  conv3d_20 (Conv3D)          (None, 10, 50, 50, 32)    4128
#
#  batch_normalization_32 (Bat  (None, 10, 50, 50, 32)   128
#  chNormalization)
#
#  max_pooling3d_20 (MaxPoolin  (None, 5, 25, 25, 32)    0
#  g3D)
#
#  conv3d_21 (Conv3D)          (None, 5, 25, 25, 64)     16448
#
#  batch_normalization_33 (Bat  (None, 5, 25, 25, 64)    256
#  chNormalization)
#
#  max_pooling3d_21 (MaxPoolin  (None, 2, 12, 12, 64)    0
#  g3D)
#
#  conv3d_22 (Conv3D)          (None, 2, 12, 12, 128)    65664
#
#  batch_normalization_34 (Bat  (None, 2, 12, 12, 128)   512
#  chNormalization)
#
#  max_pooling3d_22 (MaxPoolin  (None, 1, 6, 6, 128)     0
#  g3D)
#
#  flatten_6 (Flatten)         (None, 4608)              0
#
#  dense_18 (Dense)            (None, 256)               1179904
#
#  dense_19 (Dense)            (None, 128)               32896
#
#  dense_20 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 1,301,045
# Trainable params: 1,300,565
# Non-trainable params: 480
# _________________________________________________________________
# None
# Source path =  Project_data/train ; batch size = 64
# Epoch 1/20
# 11/11 [==============================] - ETA: 0s - loss: 4.5125 - categorical_accuracy: 0.3122 Source path =  Project_data/val ; batch size = 64
# 11/11 [==============================] - 299s 27s/step - loss: 4.5125 - categorical_accuracy: 0.3122 - val_loss: 1.6005 - val_categorical_accuracy: 0.2100 - lr: 0.0010
# Epoch 2/20
# 11/11 [==============================] - 126s 12s/step - loss: 1.3904 - categorical_accuracy: 0.5020 - val_loss: 1.4706 - val_categorical_accuracy: 0.3750 - lr: 0.0010
# Epoch 3/20
# 11/11 [==============================] - 117s 11s/step - loss: 0.9336 - categorical_accuracy: 0.6877 - val_loss: 4.5105 - val_categorical_accuracy: 0.1250 - lr: 0.0010
# Epoch 4/20
# 11/11 [==============================] - 109s 10s/step - loss: 0.7655 - categorical_accuracy: 0.6824 - val_loss: 6.2575 - val_categorical_accuracy: 0.1250 - lr: 0.0010
# Epoch 5/20
# 11/11 [==============================] - 95s 9s/step - loss: 0.4072 - categorical_accuracy: 0.8373 - val_loss: 5.4987 - val_categorical_accuracy: 0.1875 - lr: 0.0010
# Epoch 6/20
# 11/11 [==============================] - ETA: 0s - loss: 0.4214 - categorical_accuracy: 0.8708
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 11/11 [==============================] - 87s 8s/step - loss: 0.4214 - categorical_accuracy: 0.8708 - val_loss: 6.9994 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 7/20
# 11/11 [==============================] - 86s 8s/step - loss: 0.4673 - categorical_accuracy: 0.8424 - val_loss: 7.9697 - val_categorical_accuracy: 0.3750 - lr: 2.0000e-04
# Epoch 8/20
# 11/11 [==============================] - 79s 7s/step - loss: 0.2314 - categorical_accuracy: 0.8984 - val_loss: 10.6513 - val_categorical_accuracy: 0.1250 - lr: 2.0000e-04
# Epoch 9/20
# 11/11 [==============================] - 80s 7s/step - loss: 0.1500 - categorical_accuracy: 0.9572 - val_loss: 8.5430 - val_categorical_accuracy: 0.0000e+00 - lr: 2.0000e-04
# Epoch 10/20
# 11/11 [==============================] - ETA: 0s - loss: 0.1690 - categorical_accuracy: 0.9572
# Epoch 10: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 11/11 [==============================] - 80s 7s/step - loss: 0.1690 - categorical_accuracy: 0.9572 - val_loss: 3.2326 - val_categorical_accuracy: 0.2500 - lr: 2.0000e-04
# Epoch 11/20
# 11/11 [==============================] - 81s 7s/step - loss: 0.1643 - categorical_accuracy: 0.9465 - val_loss: 9.1574 - val_categorical_accuracy: 0.2500 - lr: 4.0000e-05
# Epoch 12/20
# 11/11 [==============================] - 90s 8s/step - loss: 0.1719 - categorical_accuracy: 0.9465 - val_loss: 11.2238 - val_categorical_accuracy: 0.1250 - lr: 4.0000e-05
# Epoch 13/20
# 11/11 [==============================] - 95s 9s/step - loss: 0.1315 - categorical_accuracy: 0.9840 - val_loss: 6.6125 - val_categorical_accuracy: 0.0000e+00 - lr: 4.0000e-05
# Epoch 14/20
# 11/11 [==============================] - ETA: 0s - loss: 0.0915 - categorical_accuracy: 0.9947
# Epoch 14: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 11/11 [==============================] - 94s 9s/step - loss: 0.0915 - categorical_accuracy: 0.9947 - val_loss: 5.0124 - val_categorical_accuracy: 0.3750 - lr: 4.0000e-05
# Epoch 15/20
# 11/11 [==============================] - 80s 7s/step - loss: 0.0854 - categorical_accuracy: 0.9947 - val_loss: 4.0180 - val_categorical_accuracy: 0.5000 - lr: 8.0000e-06
# Epoch 16/20
# 11/11 [==============================] - 82s 8s/step - loss: 0.1231 - categorical_accuracy: 0.9572 - val_loss: 8.8956 - val_categorical_accuracy: 0.1250 - lr: 8.0000e-06
# Epoch 17/20
# 11/11 [==============================] - 86s 8s/step - loss: 0.1330 - categorical_accuracy: 0.9679 - val_loss: 10.2807 - val_categorical_accuracy: 0.1250 - lr: 8.0000e-06
# Epoch 18/20
# 11/11 [==============================] - ETA: 0s - loss: 0.1345 - categorical_accuracy: 0.9733
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 11/11 [==============================] - 85s 8s/step - loss: 0.1345 - categorical_accuracy: 0.9733 - val_loss: 10.1825 - val_categorical_accuracy: 0.0000e+00 - lr: 8.0000e-06
# Epoch 19/20
# 11/11 [==============================] - 85s 8s/step - loss: 0.0985 - categorical_accuracy: 0.9840 - val_loss: 10.1785 - val_categorical_accuracy: 0.1250 - lr: 1.6000e-06
# Epoch 20/20
# 11/11 [==============================] - 99s 9s/step - loss: 0.1229 - categorical_accuracy: 0.9733 - val_loss: 8.0915 - val_categorical_accuracy: 0.1250 - lr: 1.6000e-06

# %%
plotModelHistory(model5_history)
# Out:
# Max. Training Accuracy 0.9946523904800415
# Max. Validaiton Accuracy 0.5

# %% [markdown]
# ### Model 6: Switching Model architecture to Conv2D+LSTM

# %%
n_frames = 20
num_epochs = 30
batch_size = 32

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

model6 = Sequential([
    TimeDistributed(Conv2D(16, make2dFilter(3), padding='same', activation='relu'), input_shape=inputShape),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D(make2dFilter(2))),

    TimeDistributed(Conv2D(32, make2dFilter(3), padding='same', activation='relu')),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D(make2dFilter(2))),

    TimeDistributed(Conv2D(64, make2dFilter(3), padding='same', activation='relu')),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D(make2dFilter(2))),

    TimeDistributed(Conv2D(128, make2dFilter(3), padding='same', activation='relu')),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D(make2dFilter(2))),

    TimeDistributed(Conv2D(256, make2dFilter(3), padding='same', activation='relu')),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D(make2dFilter(2))),

    TimeDistributed(Flatten()),
    LSTM(256),
    Dropout(0.2),

    Dense(256, activation='relu'),
    Dropout(0.2),

    Dense(5, activation='softmax')
], name="conv_2d_lstm")
model6.compile(optimizer=optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model6.summary())

model6_history = model6.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
            callbacks=callbacks_list, validation_data=val_generator, 
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Model: "conv_2d_lstm"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_16 (TimeDi  (None, 20, 100, 100, 16)  448
#  stributed)
#
#  time_distributed_17 (TimeDi  (None, 20, 100, 100, 16)  64
#  stributed)
#
#  time_distributed_18 (TimeDi  (None, 20, 50, 50, 16)   0
#  stributed)
#
#  time_distributed_19 (TimeDi  (None, 20, 50, 50, 32)   4640
#  stributed)
#
#  time_distributed_20 (TimeDi  (None, 20, 50, 50, 32)   128
#  stributed)
#
#  time_distributed_21 (TimeDi  (None, 20, 25, 25, 32)   0
#  stributed)
#
#  time_distributed_22 (TimeDi  (None, 20, 25, 25, 64)   18496
#  stributed)
#
#  time_distributed_23 (TimeDi  (None, 20, 25, 25, 64)   256
#  stributed)
#
#  time_distributed_24 (TimeDi  (None, 20, 12, 12, 64)   0
#  stributed)
#
#  time_distributed_25 (TimeDi  (None, 20, 12, 12, 128)  73856
#  stributed)
#
#  time_distributed_26 (TimeDi  (None, 20, 12, 12, 128)  512
#  stributed)
#
#  time_distributed_27 (TimeDi  (None, 20, 6, 6, 128)    0
#  stributed)
#
#  time_distributed_28 (TimeDi  (None, 20, 6, 6, 256)    295168
#  stributed)
#
#  time_distributed_29 (TimeDi  (None, 20, 6, 6, 256)    1024
#  stributed)
#
#  time_distributed_30 (TimeDi  (None, 20, 3, 3, 256)    0
#  stributed)
#
#  time_distributed_31 (TimeDi  (None, 20, 2304)         0
#  stributed)
#
#  lstm_1 (LSTM)               (None, 256)               2622464
#
#  dropout_14 (Dropout)        (None, 256)               0
#
#  dense_23 (Dense)            (None, 256)               65792
#
#  dropout_15 (Dropout)        (None, 256)               0
#
#  dense_24 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 3,084,133
# Trainable params: 3,083,141
# Non-trainable params: 992
# _________________________________________________________________
# None
# Source path =  Project_data/train ; batch size = 32
# Epoch 1/30
# 21/21 [==============================] - ETA: 0s - loss: 1.2762 - categorical_accuracy: 0.4646 Source path =  Project_data/val ; batch size = 32
# 21/21 [==============================] - 276s 13s/step - loss: 1.2762 - categorical_accuracy: 0.4646 - val_loss: 1.6561 - val_categorical_accuracy: 0.2800 - lr: 0.0010
# Epoch 2/30
# 21/21 [==============================] - 191s 9s/step - loss: 0.8921 - categorical_accuracy: 0.6729 - val_loss: 1.9865 - val_categorical_accuracy: 0.1250 - lr: 0.0010
# Epoch 3/30
# 21/21 [==============================] - 184s 9s/step - loss: 0.7752 - categorical_accuracy: 0.7096 - val_loss: 2.2850 - val_categorical_accuracy: 0.1875 - lr: 0.0010
# Epoch 4/30
# 21/21 [==============================] - 193s 9s/step - loss: 0.7157 - categorical_accuracy: 0.7419 - val_loss: 2.5701 - val_categorical_accuracy: 0.1875 - lr: 0.0010
# Epoch 5/30
# 21/21 [==============================] - ETA: 0s - loss: 0.5654 - categorical_accuracy: 0.8039
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 21/21 [==============================] - 173s 8s/step - loss: 0.5654 - categorical_accuracy: 0.8039 - val_loss: 2.8315 - val_categorical_accuracy: 0.1250 - lr: 0.0010
# Epoch 6/30
# 21/21 [==============================] - 143s 7s/step - loss: 0.5896 - categorical_accuracy: 0.7927 - val_loss: 2.3779 - val_categorical_accuracy: 0.3125 - lr: 2.0000e-04
# Epoch 7/30
# 21/21 [==============================] - 135s 7s/step - loss: 0.3754 - categorical_accuracy: 0.8627 - val_loss: 2.2312 - val_categorical_accuracy: 0.3125 - lr: 2.0000e-04
# Epoch 8/30
# 21/21 [==============================] - 143s 7s/step - loss: 0.3598 - categorical_accuracy: 0.8796 - val_loss: 2.3628 - val_categorical_accuracy: 0.1875 - lr: 2.0000e-04
# Epoch 9/30
# 21/21 [==============================] - ETA: 0s - loss: 0.2785 - categorical_accuracy: 0.9132
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 21/21 [==============================] - 160s 8s/step - loss: 0.2785 - categorical_accuracy: 0.9132 - val_loss: 2.2157 - val_categorical_accuracy: 0.1250 - lr: 2.0000e-04
# Epoch 10/30
# 21/21 [==============================] - 128s 6s/step - loss: 0.2446 - categorical_accuracy: 0.9132 - val_loss: 2.5502 - val_categorical_accuracy: 0.3125 - lr: 4.0000e-05
# Epoch 11/30
# 21/21 [==============================] - 132s 6s/step - loss: 0.2255 - categorical_accuracy: 0.9216 - val_loss: 2.9784 - val_categorical_accuracy: 0.0625 - lr: 4.0000e-05
# Epoch 12/30
# 21/21 [==============================] - 130s 6s/step - loss: 0.2063 - categorical_accuracy: 0.9412 - val_loss: 2.0519 - val_categorical_accuracy: 0.2500 - lr: 4.0000e-05
# Epoch 13/30
# 21/21 [==============================] - ETA: 0s - loss: 0.1886 - categorical_accuracy: 0.9524
# Epoch 13: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 21/21 [==============================] - 134s 6s/step - loss: 0.1886 - categorical_accuracy: 0.9524 - val_loss: 2.5268 - val_categorical_accuracy: 0.2500 - lr: 4.0000e-05
# Epoch 14/30
# 21/21 [==============================] - 131s 6s/step - loss: 0.1755 - categorical_accuracy: 0.9440 - val_loss: 3.0444 - val_categorical_accuracy: 0.0625 - lr: 8.0000e-06
# Epoch 15/30
# 21/21 [==============================] - 130s 6s/step - loss: 0.1714 - categorical_accuracy: 0.9468 - val_loss: 2.6297 - val_categorical_accuracy: 0.1875 - lr: 8.0000e-06
# Epoch 16/30
# 21/21 [==============================] - 130s 6s/step - loss: 0.1606 - categorical_accuracy: 0.9636 - val_loss: 2.1621 - val_categorical_accuracy: 0.2500 - lr: 8.0000e-06
# Epoch 17/30
# 21/21 [==============================] - ETA: 0s - loss: 0.1901 - categorical_accuracy: 0.9524
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 21/21 [==============================] - 131s 6s/step - loss: 0.1901 - categorical_accuracy: 0.9524 - val_loss: 2.6257 - val_categorical_accuracy: 0.3125 - lr: 8.0000e-06
# Epoch 18/30
# 21/21 [==============================] - 130s 6s/step - loss: 0.1433 - categorical_accuracy: 0.9664 - val_loss: 1.3912 - val_categorical_accuracy: 0.5625 - lr: 1.6000e-06
# Epoch 19/30
# 21/21 [==============================] - 133s 6s/step - loss: 0.1640 - categorical_accuracy: 0.9580 - val_loss: 2.4042 - val_categorical_accuracy: 0.3750 - lr: 1.6000e-06
# Epoch 20/30
# 21/21 [==============================] - 132s 6s/step - loss: 0.1743 - categorical_accuracy: 0.9412 - val_loss: 1.9082 - val_categorical_accuracy: 0.5000 - lr: 1.6000e-06
# Epoch 21/30
# 21/21 [==============================] - 128s 6s/step - loss: 0.1777 - categorical_accuracy: 0.9496 - val_loss: 2.2292 - val_categorical_accuracy: 0.5000 - lr: 1.6000e-06
# Epoch 22/30
# 21/21 [==============================] - ETA: 0s - loss: 0.1766 - categorical_accuracy: 0.9524
# Epoch 22: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 21/21 [==============================] - 130s 6s/step - loss: 0.1766 - categorical_accuracy: 0.9524 - val_loss: 1.7449 - val_categorical_accuracy: 0.4375 - lr: 1.6000e-06
# Epoch 23/30
# 21/21 [==============================] - 130s 6s/step - loss: 0.1695 - categorical_accuracy: 0.9552 - val_loss: 2.1211 - val_categorical_accuracy: 0.3125 - lr: 3.2000e-07
# Epoch 24/30
# 21/21 [==============================] - 131s 6s/step - loss: 0.1570 - categorical_accuracy: 0.9636 - val_loss: 0.8033 - val_categorical_accuracy: 0.8125 - lr: 3.2000e-07
# Epoch 25/30
# 21/21 [==============================] - 128s 6s/step - loss: 0.2051 - categorical_accuracy: 0.9384 - val_loss: 0.9056 - val_categorical_accuracy: 0.6250 - lr: 3.2000e-07
# Epoch 26/30
# 21/21 [==============================] - 131s 6s/step - loss: 0.1895 - categorical_accuracy: 0.9300 - val_loss: 1.0826 - val_categorical_accuracy: 0.5625 - lr: 3.2000e-07
# Epoch 27/30
# 21/21 [==============================] - 128s 6s/step - loss: 0.1737 - categorical_accuracy: 0.9496 - val_loss: 0.4050 - val_categorical_accuracy: 0.8750 - lr: 3.2000e-07
# Epoch 28/30
# 21/21 [==============================] - 133s 6s/step - loss: 0.1806 - categorical_accuracy: 0.9524 - val_loss: 1.1237 - val_categorical_accuracy: 0.5000 - lr: 3.2000e-07
# Epoch 29/30
# 21/21 [==============================] - 131s 6s/step - loss: 0.1606 - categorical_accuracy: 0.9608 - val_loss: 0.3281 - val_categorical_accuracy: 0.7500 - lr: 3.2000e-07
# Epoch 30/30
# 21/21 [==============================] - 128s 6s/step - loss: 0.1902 - categorical_accuracy: 0.9440 - val_loss: 0.5335 - val_categorical_accuracy: 0.6875 - lr: 3.2000e-07

# %%
plotModelHistory(model6_history)
# Out:
# Max. Training Accuracy 0.9663865566253662
# Max. Validaiton Accuracy 0.875

# %% [markdown]
# ### Model 7: Transfer Learning (MobileNet) with LSTM

# %%
from tensorflow.keras.applications import mobilenet

# %%
mobilenet = mobilenet.MobileNet(weights='imagenet', include_top=False)

n_frames = 20
num_epochs = 30
batch_size = 64

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

model7 = Sequential([
    TimeDistributed(mobilenet, input_shape=inputShape)
], name="mobilenet_lstm")

for layer in model7.layers:
    layer.trainable = False

model7.add(TimeDistributed(BatchNormalization()))
model7.add(TimeDistributed(MaxPooling2D(make2dFilter(2))))
model7.add(TimeDistributed(Flatten()))

model7.add(LSTM(256))
model7.add(Dropout(0.2))

model7.add(Dense(256,activation='relu'))
model7.add(Dropout(0.2))

model7.add(Dense(5, activation='softmax'))

model7.compile(optimizer=optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model7.summary())

model7_history = model7.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
            callbacks=callbacks_list, validation_data=val_generator, 
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 [==============================] - 4s 0us/step
# Model: "mobilenet_lstm"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_32 (TimeDi  (None, 20, 3, 3, 1024)   3228864
#  stributed)
#
#  time_distributed_33 (TimeDi  (None, 20, 3, 3, 1024)   4096
#  stributed)
#
#  time_distributed_34 (TimeDi  (None, 20, 1, 1, 1024)   0
#  stributed)
#
#  time_distributed_35 (TimeDi  (None, 20, 1024)         0
#  stributed)
#
#  lstm_2 (LSTM)               (None, 256)               1311744
#
#  dropout_16 (Dropout)        (None, 256)               0
#
#  dense_25 (Dense)            (None, 256)               65792
#
#  dropout_17 (Dropout)        (None, 256)               0
#
#  dense_26 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 4,611,781
# Trainable params: 1,380,869
# Non-trainable params: 3,230,912
# _________________________________________________________________
# None
# Source path =  Project_data/train ; batch size = 64
# Epoch 1/30
# 11/11 [==============================] - ETA: 0s - loss: 1.3757 - categorical_accuracy: 0.4057 Source path =  Project_data/val ; batch size = 64
# 11/11 [==============================] - 202s 19s/step - loss: 1.3757 - categorical_accuracy: 0.4057 - val_loss: 1.0665 - val_categorical_accuracy: 0.5500 - lr: 0.0010
# Epoch 2/30
# 11/11 [==============================] - 88s 8s/step - loss: 0.6136 - categorical_accuracy: 0.8221 - val_loss: 0.8926 - val_categorical_accuracy: 0.7031 - lr: 0.0010
# Epoch 3/30
# 11/11 [==============================] - 91s 9s/step - loss: 0.4958 - categorical_accuracy: 0.8300 - val_loss: 0.7085 - val_categorical_accuracy: 0.6786 - lr: 0.0010
# Epoch 4/30
# 11/11 [==============================] - 70s 7s/step - loss: 0.2547 - categorical_accuracy: 0.9185 - val_loss: 0.6016 - val_categorical_accuracy: 0.7188 - lr: 0.0010
# Epoch 5/30
# 11/11 [==============================] - 64s 6s/step - loss: 0.1447 - categorical_accuracy: 0.9761 - val_loss: 0.5356 - val_categorical_accuracy: 0.8125 - lr: 0.0010
# Epoch 6/30
# 11/11 [==============================] - 56s 5s/step - loss: 0.1355 - categorical_accuracy: 0.9617 - val_loss: 0.2437 - val_categorical_accuracy: 0.8750 - lr: 0.0010
# Epoch 7/30
# 11/11 [==============================] - 57s 5s/step - loss: 0.1235 - categorical_accuracy: 0.9655 - val_loss: 0.7406 - val_categorical_accuracy: 0.7500 - lr: 0.0010
# Epoch 8/30
# 11/11 [==============================] - 52s 5s/step - loss: 0.0984 - categorical_accuracy: 0.9840 - val_loss: 0.1884 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 9/30
# 11/11 [==============================] - 51s 5s/step - loss: 0.0878 - categorical_accuracy: 0.9786 - val_loss: 0.1449 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 10/30
# 11/11 [==============================] - 51s 5s/step - loss: 0.0704 - categorical_accuracy: 0.9840 - val_loss: 0.0345 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 11/30
# 11/11 [==============================] - 50s 5s/step - loss: 0.0510 - categorical_accuracy: 0.9840 - val_loss: 0.2288 - val_categorical_accuracy: 1.0000 - lr: 0.0010
# Epoch 12/30
# 11/11 [==============================] - 54s 5s/step - loss: 0.0201 - categorical_accuracy: 1.0000 - val_loss: 1.7253 - val_categorical_accuracy: 0.6250 - lr: 0.0010
# Epoch 13/30
# 11/11 [==============================] - 52s 5s/step - loss: 0.0241 - categorical_accuracy: 0.9947 - val_loss: 0.6747 - val_categorical_accuracy: 0.7500 - lr: 0.0010
# Epoch 14/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0332 - categorical_accuracy: 0.9893
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 11/11 [==============================] - 49s 5s/step - loss: 0.0332 - categorical_accuracy: 0.9893 - val_loss: 1.7201 - val_categorical_accuracy: 0.6250 - lr: 0.0010
# Epoch 15/30
# 11/11 [==============================] - 51s 5s/step - loss: 0.0128 - categorical_accuracy: 0.9947 - val_loss: 0.0437 - val_categorical_accuracy: 1.0000 - lr: 2.0000e-04
# Epoch 16/30
# 11/11 [==============================] - 52s 5s/step - loss: 0.0098 - categorical_accuracy: 1.0000 - val_loss: 0.4322 - val_categorical_accuracy: 0.8750 - lr: 2.0000e-04
# Epoch 17/30
# 11/11 [==============================] - 51s 5s/step - loss: 0.0127 - categorical_accuracy: 1.0000 - val_loss: 0.8564 - val_categorical_accuracy: 0.8750 - lr: 2.0000e-04
# Epoch 18/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0098 - categorical_accuracy: 1.0000
# Epoch 18: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 11/11 [==============================] - 51s 5s/step - loss: 0.0098 - categorical_accuracy: 1.0000 - val_loss: 1.2568 - val_categorical_accuracy: 0.7500 - lr: 2.0000e-04
# Epoch 19/30
# 11/11 [==============================] - 54s 5s/step - loss: 0.0084 - categorical_accuracy: 1.0000 - val_loss: 0.6274 - val_categorical_accuracy: 0.6250 - lr: 4.0000e-05
# Epoch 20/30
# 11/11 [==============================] - 51s 5s/step - loss: 0.0077 - categorical_accuracy: 1.0000 - val_loss: 1.5222 - val_categorical_accuracy: 0.6250 - lr: 4.0000e-05
# Epoch 21/30
# 11/11 [==============================] - 50s 5s/step - loss: 0.0055 - categorical_accuracy: 1.0000 - val_loss: 0.0434 - val_categorical_accuracy: 1.0000 - lr: 4.0000e-05
# Epoch 22/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0077 - categorical_accuracy: 1.0000
# Epoch 22: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 11/11 [==============================] - 49s 5s/step - loss: 0.0077 - categorical_accuracy: 1.0000 - val_loss: 0.6723 - val_categorical_accuracy: 0.8750 - lr: 4.0000e-05
# Epoch 23/30
# 11/11 [==============================] - 49s 5s/step - loss: 0.0134 - categorical_accuracy: 1.0000 - val_loss: 0.0016 - val_categorical_accuracy: 1.0000 - lr: 8.0000e-06
# Epoch 24/30
# 11/11 [==============================] - 53s 5s/step - loss: 0.0109 - categorical_accuracy: 1.0000 - val_loss: 0.8658 - val_categorical_accuracy: 0.8750 - lr: 8.0000e-06
# Epoch 25/30
# 11/11 [==============================] - 53s 5s/step - loss: 0.0058 - categorical_accuracy: 1.0000 - val_loss: 0.8972 - val_categorical_accuracy: 0.6250 - lr: 8.0000e-06
# Epoch 26/30
# 11/11 [==============================] - 52s 5s/step - loss: 0.0054 - categorical_accuracy: 1.0000 - val_loss: 0.3158 - val_categorical_accuracy: 0.8750 - lr: 8.0000e-06
# Epoch 27/30
# 11/11 [==============================] - ETA: 0s - loss: 0.0060 - categorical_accuracy: 1.0000
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 11/11 [==============================] - 50s 5s/step - loss: 0.0060 - categorical_accuracy: 1.0000 - val_loss: 0.0380 - val_categorical_accuracy: 1.0000 - lr: 8.0000e-06
# Epoch 28/30
# 11/11 [==============================] - 53s 5s/step - loss: 0.0042 - categorical_accuracy: 1.0000 - val_loss: 1.9577 - val_categorical_accuracy: 0.6250 - lr: 1.6000e-06
# Epoch 29/30
# 11/11 [==============================] - 51s 5s/step - loss: 0.0056 - categorical_accuracy: 1.0000 - val_loss: 1.1324 - val_categorical_accuracy: 0.6250 - lr: 1.6000e-06
# Epoch 30/30
# 11/11 [==============================] - 49s 5s/step - loss: 0.0072 - categorical_accuracy: 1.0000 - val_loss: 1.5818 - val_categorical_accuracy: 0.6250 - lr: 1.6000e-06

# %%
plotModelHistory(model7_history)
# Out:
# Max. Training Accuracy 1.0
# Max. Validaiton Accuracy 1.0
